# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd(), ".."))

from src.data.dataset import ASLAlphabetDataset

# %%
dataset = ASLAlphabetDataset()
dataset.prepare_data()
dataset.setup()

# %%
trainloader = dataset.train_dataloader()
valloader = dataset.val_dataloader()

for i, (x, y) in enumerate(trainloader):
    print(x.shape)
    print(y.shape)
    break

for i, (x, y) in enumerate(valloader):
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([32, 3, 200, 200])
# torch.Size([32])
# torch.Size([32, 3, 200, 200])
# torch.Size([32])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x[i].permute(1, 2, 0).cpu().numpy())
    plt.title(dataset.label_to_class[y[i].item()])
    plt.axis("off")
    
plt.show()
